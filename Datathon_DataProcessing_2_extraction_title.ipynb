# %% [markdown]
# <a href="https://colab.research.google.com/github/IdaWiweka/datathon/blob/IdaWiweka/Datathon_DataProcessing_2_extraction_title.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import login
from google.colab import userdata
huggingface_token = userdata.get('huggingface_llama32')

# Login using the token
login(huggingface_token)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import json
import torch
from transformers import pipeline
from tqdm import tqdm


# Define the folder path
folder_path = '/content/drive/My Drive/processed_batches/Dataset_id'
file_path = '/content/drive/My Drive/processed_batches/Dataset_id/title_extraction_1.csv'

# Read the CSV file
file_name = "epiwatch-latest.csv"

data = pd.read_csv(os.path.join(folder_path, file_name))

# Filter the data to include only rows with id from 1 to 50
filtered_data = data[data['report_id'].between(1, 20)]

# Set the device
device = 0 if torch.cuda.is_available() else -1  # 0 for CUDA, -1 for CPU

# Parameters
parameters = {
    "model_name": "meta-llama/Llama-3.2-3B-Instruct",
    "device": device,
    "torch_dtype": torch.bfloat16,
    "temperature": 0.2,
    "top_p": 0.9,
    "max_new_tokens": 128,
    "text_column": "title",  # Replace with the actual column name in your CSV
    "id_column": "report_id"        # Replace with the actual column name in your CSV
}

def extract_information_from_dataframe(
    dataframe,
    model_name,
    device,
    torch_dtype,
    temperature,
    top_p,
    max_new_tokens,
    text_column,
    id_column
):
    """
    Extract structured information from a DataFrame using a language model pipeline.
    """
    # Set the device
    # Initialize the pipeline
    generator = pipeline("text-generation", model=model_name, device=device, torch_dtype=torch_dtype)

    # Prepare results list
    results = []

    # Iterate through the DataFrame rows
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe), desc="Processing rows"):
        data = row["title"]
        unique_id = row["report_id"]

        # Prepare the prompt
        prompt = [
                {
                    "role": "system",
                    "content": """You are an epidemiologist. Your task is to extract information from unstructured text data.\n

                                  Specifically, you will identify and extract:\n
                                  - The number of cases (incidence or prevalence), if none = NA.\n
                                  - The number of mortality (dead or kill), if none = NA.\n
                                  - The name of the disease(s), if none = NA.\n
                                  - The name of the syndrome(s), if none = NA.\n
                                  - The location(s) where the case(s) occurred, if none = NA.\n
                                  - Determine if it is an "outbreak", "increase", "decrease", "decline", "new", "rise", or "alert" or any synonym of those words, if none = NA.\n

                                  There are seven example of diseases:\n
                                  Influenza (many strains), Covid-19, Mpox, Legionnaires', Dengue, Measles, Cholera\n
                                  However, it also potentially any other diseases outside the list.\n

                                  The syndromes refer to more generalised symptoms, usually recorded when the disease is unknown. Common syndromes include\n
                                  Acute gastroenteritis, Severe acute respiratory syndrome, Febrile syndromes, Pneumonia, Influenza-like illness.\n


                                  Example 1:\n
                                  The data: "271 new cases of corona virus infection in Odisha, two patients killed - Navbharat Times"\n
                                  The Output:\n
                                  "cases": "271",\n
                                  "dead": "2",\n
                                  "disease": "corona virus infection",\n
                                  "syndrome": "NA",\n
                                  "location": "Odisha",\n
                                  "keywords": "new"\n

                                  Example 2:\n
                                  The data: "Alert in Europe for new cases of avian influenza | Agrofy News"\n
                                  The Output:\n
                                  "cases": "NA",\n
                                  "dead": "NA",\n
                                  "disease": "avian influenza",\n
                                  "syndrome": "NA",\n
                                  "locations": "Europe",\n
                                  "transmission": "NA",\n
                                  "keywords": "new, alert"\n

                                  Example 3:\n
                                  The data: "CIDRAP - India's COVID-19 total tops 5 million as cases rise in Europe"\n
                                  The Output:\n
                                  "cases": "5000000",\n
                                  "dead": "NA",\n
                                  "disease": "COVID-19",\n
                                  "syndrome": "NA",\n
                                  "locations": "Europe",\n
                                  "keywords": "rise"\n

                                  Example 4:\n
                                  The data: "New Crown Pneumonia in the United States confirmed 6.59 million deaths over 195,000;"\n
                                  The Output:\n
                                  "cases": "6590000",\n
                                  "dead": "195000",\n
                                  "disease": "NA",\n
                                  "syndrome": "Pneumonia",\n
                                  "locations": "United States",\n
                                  "keywords": "new"\n

                                  Example 5:\n
                                  The data: "Nearly half a million children in the United States have been infected with the new coronavirus;\n"
                                  The Output:\n
                                  "cases": "500000",\n
                                  "dead": "NA",\n
                                  "disease": "coronavirus",\n
                                  "syndrome": "NA",\n
                                  "locations": "United States",\n
                                  "keywords": "new"\n

                                  Example 6:\n
                                  The data: "US - Approx. a daily increase of 46,425 cases, 1,076 deaths for totals of 6,649,458 cases,Â 197,223 deathsÂ - Fauci says enough people have to take a Covid-19 vaccine to be efficient - September 17, 2020;\n"
                                  The Output:\n
                                  "cases": "46425",\n
                                  "dead": "1076",\n
                                  "disease": "Covid-19",\n
                                  "syndrome": "NA",\n
                                  "locations": "US",\n
                                  "keywords": "daily increase"\n

                                  Example 7:\n
                                  The data: "Also the scourge of infectious diseases: 38 people suffering from fever in 15 days ...;\n"
                                  The Output:\n
                                  "cases": "38",\n
                                  "dead": "NA",\n
                                  "disease": "NA",\n
                                  "syndrome": "fever",\n
                                  "locations": "NA",\n
                                  "keywords": "daily increase"\n

                                  Return your response in JSON format without any additional explanation.\n""",
                },
                {
                    "role": "user",
                    "content": f"""Here is the data:\n
                                  "{data}"
                                  Extract the required information.\n""",
                },
            ]

        # Generate the response
        generation = generator(
            prompt,
            do_sample=True,
            temperature=temperature,
            top_p=top_p,
            max_new_tokens=max_new_tokens
        )

        # Extract the JSON-like respons
        assistant_response = generation[0]["generated_text"]
        assistant_content = assistant_response[2]['content']
        # Add results to the list
        results.append({
            id_column: unique_id,
            "extracted_info": assistant_content
        })

    return results

# Example usage
results = extract_information_from_dataframe(
    dataframe=filtered_data,
    **parameters
)

# Print the results in a readable format
print(json.dumps(results, indent=4))



def parse_extracted_info(info):
    try:
        # Remove backticks and strip any extra spaces
        cleaned_info = info.strip("```").strip()
        # Convert the string to a dictionary
        return json.loads(cleaned_info)
    except json.JSONDecodeError:
        return {}

# Create a DataFrame
df = pd.DataFrame(results)

# Parse the 'extracted_info' column into dictionaries
df['parsed_info'] = df['extracted_info'].apply(parse_extracted_info)

# Expand the parsed_info dictionary into separate columns
parsed_df = pd.json_normalize(df['parsed_info'])

# Combine the parsed information with the original ID column
final_df = pd.concat([df[['report_id']], parsed_df], axis=1)

print(final_df)

# Convert 'report-id' column in df1 to string (object) type
data['report_id'] = data['report_id'].astype(int)

# Merge the two DataFrames on 'report-id'
merged_df = pd.merge(data, final_df, on='report_id', how='inner')

print(merged_df)

# Save and download the file
#merged_df.to_csv('extracted.csv', index=False)
#files.download('extracted.csv')
# Save the DataFrame to a CSV file
merged_df.to_csv(file_path, index=False)

print(f"File saved to {file_path}")
print("DataFrame has been saved to 'csv'")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing rows:   0%|          | 0/20 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:   5%|▌         | 1/20 [00:01<00:26,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  10%|█         | 2/20 [00:02<00:26,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  15%|█▌        | 3/20 [00:04<00:25,  1.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  20%|██        | 4/20 [00:06<00:24,  1.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  25%|██▌       | 5/20 [00:07<00:22,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  30%|███       | 6/20 [00:09<00:21,  1.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  35%|███▌      | 7/20 [00:10<00:18,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  40%|████      | 8/20 [00:11<00:16,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  45%|████▌     | 9/20 [00:13<00:15,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  50%|█████     | 10/20 [00:14<00:14,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  55%|█████▌    | 11/20 [00:16<00:12,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  60%|██████    | 12/20 [00:17<00:12,  1.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  65%|██████▌   | 13/20 [00:19<00:10,  1.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  70%|███████   | 14/20 [00:20<00:09,  1.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  75%|███████▌  | 15/20 [00:22<00:07,  1.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  80%|████████  | 16/20 [00:23<00:06,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  85%|████████▌ | 17/20 [00:25<00:04,  1.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  90%|█████████ | 18/20 [00:26<00:03,  1.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows:  95%|█████████▌| 19/20 [00:28<00:01,  1.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Processing rows: 100%|██████████| 20/20 [00:30<00:00,  1.50s/it]
# [
#     {
#         "report_id": 1,
#         "extracted_info": "{\"cases\": \"90123\", \"dead\": \"NA\", \"disease\": \"NA\", \"syndrome\": \"NA\", \"location\": \"NA\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 2,
#         "extracted_info": "{\"cases\": \"NA\", \"dead\": \"NA\", \"disease\": \"NA\", \"syndrome\": \"NA\", \"location\": \"Ludhiana District\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 3,
#         "extracted_info": "{\"cases\": \"5000000\", \"dead\": \"NA\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"locations\": \"Europe\", \"keywords\": \"rise\"}"
#     },
#     {
#         "report_id": 4,
#         "extracted_info": "{\"cases\": \"426\", \"dead\": \"26\", \"disease\": \"NA\", \"syndrome\": \"NA\", \"location\": \"LOUISIANA\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 5,
#         "extracted_info": "{\"cases\": \"498\", \"dead\": \"9\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"New Jersey\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 6,
#         "extracted_info": "{\"cases\": \"1466\", \"dead\": \"20\", \"disease\": \"coronavirus\", \"syndrome\": \"NA\", \"location\": \"ILLINOIS\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 7,
#         "extracted_info": "{\"cases\": \"175231\", \"dead\": \"2127\", \"disease\": \"COVID-19\", \"location\": \"Tennessee\", \"keywords\": \"reported\"}"
#     },
#     {
#         "report_id": 8,
#         "extracted_info": "{\"cases\": \"113183\", \"dead\": \"6612\", \"disease\": \"COVID-19\", \"location\": \"MI\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 9,
#         "extracted_info": "{\"cases\": \"701\", \"dead\": \"22\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"S.C.\", \"keywords\": \"new, additional\"}"
#     },
#     {
#         "report_id": 10,
#         "extracted_info": "{\"cases\": \"1001\", \"dead\": \"87\", \"disease\": \"NA\", \"syndrome\": \"NA\", \"location\": \"OHIO\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 11,
#         "extracted_info": "{\"cases\": \"2233\", \"dead\": \"12\", \"disease\": \"new cases of Telangana\", \"location\": \"Telangana\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 12,
#         "extracted_info": "{\n  \"cases\": \"4000\",\n  \"dead\": \"NA\",\n  \"disease\": \"covid\",\n  \"syndrome\": \"NA\",\n  \"location\": \"Oxford, United Kingdom\",\n  \"keywords\": \"rise\"\n}"
#     },
#     {
#         "report_id": 13,
#         "extracted_info": "{\"cases\": \"NA\", \"dead\": \"NA\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"Philadelphia\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 14,
#         "extracted_info": "{\"cases\": \"220\", \"dead\": \"10\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"WEST VIRGINIA\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 15,
#         "extracted_info": "{\"cases\": \"845\", \"dead\": \"45\", \"disease\": \"NA\", \"syndrome\": \"NA\", \"location\": \"Virginia\", \"keywords\": \"new, reported\"}"
#     },
#     {
#         "report_id": 16,
#         "extracted_info": "{\"cases\": \"42\", \"dead\": \"NA\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"Victoria\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 17,
#         "extracted_info": "{\"cases\": \"161\", \"dead\": \"NA\", \"disease\": \"Covid\", \"syndrome\": \"NA\", \"location\": \"Kannur\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 18,
#         "extracted_info": "{\"cases\": \"368\", \"dead\": \"NA\", \"disease\": \"coronavirus\", \"syndrome\": \"NA\", \"location\": \"Sverdlovsk region\", \"keywords\": \"NA\"}"
#     },
#     {
#         "report_id": 19,
#         "extracted_info": "{\"cases\": \"286\", \"dead\": \"6\", \"disease\": \"COVID-19\", \"syndrome\": \"NA\", \"location\": \"NA\", \"keywords\": \"new\"}"
#     },
#     {
#         "report_id": 20,
#         "extracted_info": "{\"cases\": \"6590000\", \"dead\": \"195000\", \"disease\": \"NA\", \"syndrome\": \"Pneumonia\", \"locations\": \"United States\", \"keywords\": \"new\"}"
#     }
# ]
#     report_id    cases    dead                 disease   syndrome  \
# 0           1    90123      NA                      NA         NA
# 1           2       NA      NA                      NA         NA
# 2           3  5000000      NA                COVID-19         NA
# 3           4      426      26                      NA         NA
# 4           5      498       9                COVID-19         NA
# 5           6     1466      20             coronavirus         NA
# 6           7   175231    2127                COVID-19        NaN
# 7           8   113183    6612                COVID-19        NaN
# 8           9      701      22                COVID-19         NA
# 9          10     1001      87                      NA         NA
# 10         11     2233      12  new cases of Telangana        NaN
# 11         12     4000      NA                   covid         NA
# 12         13       NA      NA                COVID-19         NA
# 13         14      220      10                COVID-19         NA
# 14         15      845      45                      NA         NA
# 15         16       42      NA                COVID-19         NA
# 16         17      161      NA                   Covid         NA
# 17         18      368      NA             coronavirus         NA
# 18         19      286       6                COVID-19         NA
# 19         20  6590000  195000                      NA  Pneumonia
#
#                   location         keywords      locations
# 0                       NA               NA            NaN
# 1        Ludhiana District               NA            NaN
# 2                      NaN             rise         Europe
# 3                LOUISIANA              new            NaN
# 4               New Jersey              new            NaN
# 5                 ILLINOIS              new            NaN
# 6                Tennessee         reported            NaN
# 7                       MI               NA            NaN
# 8                     S.C.  new, additional            NaN
# 9                     OHIO              new            NaN
# 10               Telangana              new            NaN
# 11  Oxford, United Kingdom             rise            NaN
# 12            Philadelphia               NA            NaN
# 13           WEST VIRGINIA              new            NaN
# 14                Virginia    new, reported            NaN
# 15                Victoria               NA            NaN
# 16                  Kannur               NA            NaN
# 17       Sverdlovsk region               NA            NaN
# 18                      NA              new            NaN
# 19                     NaN              new  United States
#                                                 title publication-date  \
# 0   90123 people sick in one day in the country; D...       2020-09-16
# 1         Ludhiana District remains at receiving end;       2020-09-16
# 2   CIDRAP - India's COVID-19 total tops 5 million...       2020-09-16
# 3   [Myarklamiss.com] LOUISIANA - State reports 42...       2020-09-15
# 4   [1010 WINS] NEW JERSEY - New Jersey reports 9 ...       2020-09-15
# 5   [WLS] ILLINOIS - Pritzker warns of budget cuts...       2020-09-15
# 6   [Wrcbtv.com] TENNESSEE - 175,231 COVID-19 case...       2020-09-15
# 7   [WKZO] MICHIGAN - 113,183 COVID-19 cases in MI...       2020-09-15
# 8   [WCSC] SOUTH CAROLINA - S.C. reports 701 new c...       2020-09-15
# 9   [WCMH] OHIO - 1,001 new cases, 87 additional d...       2020-09-15
# 10  [Telanganatoday.com] INDIA - 2,273 new cases, ...       2020-09-15
# 11  [banburycake.co.uk] UNITED KINGDOM - Oxford co...       2020-09-16
# 12  [CBS] PENNSYLVANIA - White House Staff Members...       2020-09-16
# 13  [Wtrf.com] WEST VIRGINIA - DHHR confirms 10 ne...       2020-09-16
# 14  [Wavy.com] VIRGINIA - 845 new cases, 45 new de...       2020-09-16
# 15  [Theage.com.au] AUSTRALIA - Victoria records 4...       2020-09-16
# 16    Covid for 14 health workers in Kannur: 161 ...;       2020-09-16
# 17  In the Sverdlovsk region, 368 classes have alr...       2020-09-16
# 18  Mass . reports 6 new COVID-19 deaths , 286 new...       2020-09-16
# 19  New Crown Pneumonia in the United States confi...       2020-09-16
#
#     event-date             country  \
# 0   2017-09-16               India
# 1   2020-09-16               India
# 2   2020-09-16               India
# 3   2020-09-15       United States
# 4   2020-09-15       United States
# 5   2020-09-15       United States
# 6   2020-09-15       United States
# 7   2020-09-15       United States
# 8   2020-09-15       United States
# 9   2020-09-15       United States
# 10  2020-09-15               India
# 11  2020-09-16      United Kingdom
# 12  2020-09-16       United States
# 13  2020-09-16       United States
# 14  2020-09-16       United States
# 15  2020-09-16           Australia
# 16  2020-09-16               India
# 17  2020-09-16  Russian Federation
# 18  2020-09-16       United States
# 19  2020-09-15       United States
#
#                                            location_x         lat_long  \
# 0                                                 NaN   23.379, 79.443
# 1                          Punjab, Ludhiana, Ludhiana   30.907, 75.849
# 2                                                 NaN   23.379, 79.443
# 3                                           Louisiana  30.186, -91.426
# 4                                          New Jersey  39.613, -74.729
# 5                                            Illinois  40.114, -89.159
# 6                                           Tennessee  35.843, -86.343
# 7                                            Michigan  44.125, -84.197
# 8                                      South Carolina  33.904, -80.894
# 9                                                Ohio  40.413, -82.711
# 10                                                NaN   23.379, 79.443
# 11                               England, Oxfordshire   51.766, -1.322
# 12  Pennsylvania, Philadelphia County, Philadelphi...  39.952, -75.162
# 13          West Virginia, Kanawha County, Charleston   38.35, -81.639
# 14               Virginia, City of Richmond, Richmond  37.541, -77.434
# 15                                                NaN  -25.71, 134.484
# 16                             Kerala, Kannur, Kannur   11.875, 75.375
# 17                        Sverdlovsk, Catharinoburgum   56.858, 60.613
# 18                                      Massachusetts  42.359, -71.718
# 19                                                NaN  39.399, -99.415
#
#    diseases                          syndromes  \
# 0   covid19                                NaN
# 1     other  severe acute respiratory syndrome
# 2   covid19                                NaN
# 3   covid19                                NaN
# 4   covid19                                NaN
# 5   covid19                                NaN
# 6   covid19                                NaN
# 7   covid19                                NaN
# 8   covid19                                NaN
# 9   covid19                                NaN
# 10  covid19                                NaN
# 11  covid19                                NaN
# 12  covid19                                NaN
# 13  covid19                                NaN
# 14  covid19                                NaN
# 15  covid19                                NaN
# 16  covid19                                NaN
# 17  covid19                                NaN
# 18  covid19                                NaN
# 19  covid19                                NaN
#
#                                                   url  report_id    cases  \
# 0   https://www.manoramaonline.com/news/latest-new...          1    90123
# 1   https://www.tribuneindia.com/news/ludhiana/lud...          2       NA
# 2   https://flutrackers.com/forum/forum/local-regi...          3  5000000
# 3   http://outbreaks.globalincidentmap.com/eventde...          4      426
# 4   http://outbreaks.globalincidentmap.com/eventde...          5      498
# 5   http://outbreaks.globalincidentmap.com/eventde...          6     1466
# 6   http://outbreaks.globalincidentmap.com/eventde...          7   175231
# 7   http://outbreaks.globalincidentmap.com/eventde...          8   113183
# 8   http://outbreaks.globalincidentmap.com/eventde...          9      701
# 9   http://outbreaks.globalincidentmap.com/eventde...         10     1001
# 10  http://outbreaks.globalincidentmap.com/eventde...         11     2233
# 11  http://outbreaks.globalincidentmap.com/eventde...         12     4000
# 12  http://outbreaks.globalincidentmap.com/eventde...         13       NA
# 13  http://outbreaks.globalincidentmap.com/eventde...         14      220
# 14  http://outbreaks.globalincidentmap.com/eventde...         15      845
# 15  http://outbreaks.globalincidentmap.com/eventde...         16       42
# 16  https://malayalam.oneindia.com/news/kannur/14-...         17      161
# 17  https://www.znak.com/2020-09-15/v_sverdlovskoy...         18      368
# 18  https://www.boston.com/news/coronavirus/2020/0...         19      286
# 19  http://world.people.com.cn/n1/2020/0916/c1002-...         20  6590000
#
#       dead                 disease   syndrome              location_y  \
# 0       NA                      NA         NA                      NA
# 1       NA                      NA         NA       Ludhiana District
# 2       NA                COVID-19         NA                     NaN
# 3       26                      NA         NA               LOUISIANA
# 4        9                COVID-19         NA              New Jersey
# 5       20             coronavirus         NA                ILLINOIS
# 6     2127                COVID-19        NaN               Tennessee
# 7     6612                COVID-19        NaN                      MI
# 8       22                COVID-19         NA                    S.C.
# 9       87                      NA         NA                    OHIO
# 10      12  new cases of Telangana        NaN               Telangana
# 11      NA                   covid         NA  Oxford, United Kingdom
# 12      NA                COVID-19         NA            Philadelphia
# 13      10                COVID-19         NA           WEST VIRGINIA
# 14      45                      NA         NA                Virginia
# 15      NA                COVID-19         NA                Victoria
# 16      NA                   Covid         NA                  Kannur
# 17      NA             coronavirus         NA       Sverdlovsk region
# 18       6                COVID-19         NA                      NA
# 19  195000                      NA  Pneumonia                     NaN
#
#            keywords      locations
# 0                NA            NaN
# 1                NA            NaN
# 2              rise         Europe
# 3               new            NaN
# 4               new            NaN
# 5               new            NaN
# 6          reported            NaN
# 7                NA            NaN
# 8   new, additional            NaN
# 9               new            NaN
# 10              new            NaN
# 11             rise            NaN
# 12               NA            NaN
# 13              new            NaN
# 14    new, reported            NaN
# 15               NA            NaN
# 16               NA            NaN
# 17               NA            NaN
# 18              new            NaN
# 19              new  United States
# File saved to /content/drive/My Drive/processed_batches/Dataset_id/extracted.csv
# DataFrame has been saved to 'csv'
